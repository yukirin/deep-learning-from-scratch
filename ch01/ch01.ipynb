# %%
7 / 5
# Out:
# 1.4

# %%
7 // 5
# Out:
# 1

# %%
7 // 5
# Out:
# 1

# %%
type(10)
# Out:
# int

# %%
a = [1, 2, 3, 4, 5]
a[::-1]
# Out:
# [5, 4, 3, 2, 1]

# %%
True
False
# Out:
# False

# %%
import numpy as np

# %%
x = np.array([1.0, 2.0, 3.0])
print(x)
type(x)
# Out:
# [ 1.  2.  3.]
# numpy.ndarray

# %%
x
# Out:
# array([ 1.,  2.,  3.])

# %%
y = np.array([2.0, 4.0, 6.0])

# %%
x + y
# Out:
# array([ 3.,  6.,  9.])

# %%
x - y
# Out:
# array([-1., -2., -3.])

# %%
x * y
# Out:
# array([  2.,   8.,  18.])

# %%
x / y
# Out:
# array([ 0.5,  0.5,  0.5])

# %%
x @ y
# Out:
# 28.0

# %%
x * 5
# Out:
# array([  5.,  10.,  15.])

# %%
A = np.array([[1, 2], [3, 4]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
A.shape
# Out:
# (2, 2)

# %%
a.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f848ce086b5c> in <module>()
# ----> 1 a.dtype
#
# NameError: name 'a' is not defined

# %%
A.dtype
# Out:
# dtype('int64')

# %%
B = np.array([[3, 0], [0, 6]])

# %%
A + B
# Out:
# array([[ 4,  2],
#        [ 3, 10]])

# %%
A * B
# Out:
# array([[ 3,  0],
#        [ 0, 24]])

# %%
10 * A
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
A = np.array([[1, 2], [3, 4]])

# %%
B = np.array([10, 20])

# %%
A * B
# Out:
# array([[10, 40],
#        [30, 80]])

# %%
AF = A.flatten()
AF
# Out:
# array([1, 2, 3, 4])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
AF[[0, 2, 4]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-57481a922e34> in <module>()
# ----> 1 AF[[0, 2, 4]]
#
# IndexError: index 4 is out of bounds for axis 1 with size 4

# %%
AF[np.array([0, 2, 3])]
# Out:
# array([1, 3, 4])

# %%
AF[[0, 2, 3]]
# Out:
# array([1, 3, 4])

# %%
AF > 2
# Out:
# array([False, False,  True,  True], dtype=bool)

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
A > 1
# Out:
# array([[False,  True],
#        [ True,  True]], dtype=bool)

# %%
A[A > 1]
# Out:
# array([2, 3, 4])

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 6, 0.1)

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
plt.show()

# %%
plt.plot(x, y)
plt.show()

# %%
x = np.arange(0, 6, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
y2 = np.cos(x)
plt.plot(x, y, label="sin")
plt.plot(x, y2, label="cos", linestyle = "--")
plt.xlabel("x")
plt.ylabel("y")
plt.title('sin & cos')
plt.legend()
plt.show()

# %%
from matplotlib.image import imread

img = imread('../dataset/lena.png')
plt.imshow(img)
plt.show()
